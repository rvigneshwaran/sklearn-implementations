# %%
# Import necessary libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.cluster import Birch
from sklearn import datasets
from sklearn.metrics import silhouette_score
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# %%
# Load the Iris dataset
iris = datasets.load_iris()
iris_df = pd.DataFrame(data=np.c_[iris['data'], iris['target']],
                       columns=iris['feature_names'] + ['target'])

# %%
# Feature Selection
features = ['sepal length (cm)', 'sepal width (cm)']

# %%
# Split the data into training and testing sets
train_data, test_data = train_test_split(iris_df[features], test_size=0.2, random_state=42)

# %%
# Preprocessing
def preprocess_data(data, features):
    X = data[features]
    scaler = StandardScaler()
    X_scaled = scaler.fit_transform(X)
    return X_scaled

# %%
# Train the Birch Clustering model
def train_birch(X, threshold, n_clusters):
    model = Birch(threshold=threshold, n_clusters=n_clusters)
    labels = model.fit_predict(X)
    return model, labels

# %%
# Visualize the clusters
def visualize_clusters(X, labels, title):
    plt.scatter(X[:, 0], X[:, 1], c=labels, cmap='viridis', edgecolor='k')
    plt.xlabel(features[0])
    plt.ylabel(features[1])
    plt.title(title)
    plt.show()

# %%
# Evaluate the clustering
def evaluate_clustering(X, labels):
    silhouette_avg = silhouette_score(X, labels)
    return silhouette_avg

# %%
# Preprocess the training data
X_train_scaled = preprocess_data(train_data, features)

# %%
# Train Birch Clustering model
threshold = 0.5  # You can adjust the threshold based on your requirement
n_clusters = 3  # You can adjust the number of clusters based on your requirement
birch_model, train_labels = train_birch(X_train_scaled, threshold, n_clusters)

# %%
# Visualize clusters on the training set
visualize_clusters(X_train_scaled, train_labels, 'Birch Clustering - Training Set')

# %%
# Preprocess the test data
X_test_scaled = preprocess_data(test_data, features)

# %%
# Predict clusters on the test set
test_labels = birch_model.fit_predict(X_test_scaled)

# %%
# Visualize clusters on the test set
visualize_clusters(X_test_scaled, test_labels, 'Birch Clustering - Test Set')

# %%
# Evaluate clustering on the training set
silhouette_avg_train = evaluate_clustering(X_train_scaled, train_labels)
print(f'Silhouette Score (Training Set): {silhouette_avg_train}')
# Out:
# Silhouette Score (Training Set): 0.45070310662367186

# %%
# Evaluate clustering on the test set
silhouette_avg_test = evaluate_clustering(X_test_scaled, test_labels)
print(f'Silhouette Score (Test Set): {silhouette_avg_test}')
# Out:
# Silhouette Score (Test Set): 0.45270921621706184
